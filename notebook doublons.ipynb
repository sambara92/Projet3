# %%
import pandas as pd

# %%
aeronefs = pd.read_csv(r"C:\Users\MAITE\Wild Code School\SkyAnalytics\BDD\fixes\aeronefs_2024-06-02.csv")
composants = pd.read_csv(r"C:\Users\MAITE\Wild Code School\SkyAnalytics\BDD\fixes\composants_2024-06-02.csv")

# %%
aeronefs.head()
# Out:
#       ref_aero type_model debut_service           last_maint  en_maintenance  \
# 0    E170_6353       E170    2000-03-17  2024-03-27 00:00:00           False
# 1    B767_2803       B767    2020-12-03  2024-06-01 00:00:00           False
# 2  CRJ700_6943     CRJ700    2015-01-29           2024-06-02            True
# 3    A350_1177       A350    2005-08-07  2024-01-04 00:00:00           False
# 4    B777_4029       B777    2009-01-01  2024-06-01 00:00:00           False
#
#              end_maint
# 0                  NaN
# 1                  NaN
# 2  2024-06-03 14:13:00
# 3                  NaN
# 4                  NaN

# %%
aeronefs.duplicated(subset='ref_aero')
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 227    False
# 228    False
# 229    False
# 230     True
# 231    False
# Length: 232, dtype: bool

# %%
aeronefs[aeronefs.duplicated(subset='ref_aero') == True]
# Out:
#       ref_aero type_model debut_service           last_maint  en_maintenance  \
# 230  E170_5551       E170    2021-04-10  2024-06-01 00:00:00           False
#
#     end_maint
# 230       NaN

# %%
aeronefs.loc[aeronefs['ref_aero'] == 'E170_5551']
# Out:
#      ref_aero type_model debut_service           last_maint  en_maintenance  \
# 40  E170_5551       E170    2017-02-07  2024-06-01 00:00:00           False
#
#    end_maint
# 40       NaN

# %%
aeronefs = aeronefs.drop_duplicates(subset='ref_aero', keep='first')

# %%
composants.head()
# Out:
#              ref_compo             categorie       aero  \
# 0  REAE170-E170_6353-0  Composants Critiques  E170_6353
# 1  REAE170-E170_6353-1  Composants Critiques  E170_6353
# 2  SYSE170-E170_6353-2  Composants Critiques  E170_6353
# 3  ORDE170-E170_6353-3  Composants Critiques  E170_6353
# 4  AUTE170-E170_6353-4  Composants Critiques  E170_6353
#
#                     desc  lifespan  taux_usure_actuel   cout
# 0        Réacteur gauche     13045          53.308375  15552
# 1         Réacteur droit     13626          50.111950  17559
# 2  Système de navigation     10541          16.730575  16514
# 3      Ordinateur de vol     10441           6.653075  16047
# 4             Autopilote     14847          42.033525  19362

# %%
composants.duplicated(subset=['ref_compo', 'lifespan']).sum()
# Out:
# 45

# %%
composants.duplicated(subset='ref_compo').sum()
# Out:
# 45

# %%
composants[composants.duplicated(subset=['ref_compo', 'lifespan']) == True]
# Out:
#                   ref_compo               categorie       aero  \
# 10350   REAE170-E170_5551-0    Composants Critiques  E170_5551
# 10351   REAE170-E170_5551-1    Composants Critiques  E170_5551
# 10352   SYSE170-E170_5551-2    Composants Critiques  E170_5551
# 10353   ORDE170-E170_5551-3    Composants Critiques  E170_5551
# 10354   AUTE170-E170_5551-4    Composants Critiques  E170_5551
# 10355   SYSE170-E170_5551-5    Composants Critiques  E170_5551
# 10356   RADE170-E170_5551-6    Composants Critiques  E170_5551
# 10357   SYSE170-E170_5551-7    Composants Critiques  E170_5551
# 10358   SYSE170-E170_5551-8    Composants Critiques  E170_5551
# 10359   SYSE170-E170_5551-9    Composants Critiques  E170_5551
# 10360  SYSE170-E170_5551-10    Composants Critiques  E170_5551
# 10361  UNIE170-E170_5551-11    Composants Critiques  E170_5551
# 10362  SYSE170-E170_5551-12    Composants Critiques  E170_5551
# 10363  SYSE170-E170_5551-13    Composants Critiques  E170_5551
# ...

# %%
composants.shape
# Out:
# (10440, 7)

# %%
composants.duplicated(subset='ref_compo').sum()
# Out:
# 45

# %%
10440-45
# Out:
# 10395

# %%
composants.loc[composants['ref_compo'] == 'REAE170-E170_5551-0']
# Out:
#                  ref_compo             categorie       aero             desc  \
# 1800   REAE170-E170_5551-0  Composants Critiques  E170_5551  Réacteur gauche
# 10350  REAE170-E170_5551-0  Composants Critiques  E170_5551  Réacteur gauche
#
#        lifespan  taux_usure_actuel   cout
# 1800      13045           33.47277  15552
# 10350     13045            9.80000  15552

# %%
composants.loc[composants['ref_compo'] == 'FLAE170-E170_5551-22']
# Out:
#                   ref_compo           categorie       aero   desc  lifespan  \
# 1822   FLAE170-E170_5551-22  Composants Majeurs  E170_5551  Flaps     11025
# 10372  FLAE170-E170_5551-22  Composants Majeurs  E170_5551  Flaps     11025
#
#        taux_usure_actuel   cout
# 1822            27.13865  14480
# 10372           47.44000  14480

# %%
compo_final = composants.groupby('ref_compo')[['categorie','aero','desc','lifespan','taux_usure_actuel','cout']].max()

# %%
compo_final = compo_final.reset_index()

# %%
compo_final
# Out:
#                   ref_compo             categorie       aero  \
# 0      AILA320-A320_1884-20    Composants Majeurs  A320_1884
# 1      AILA320-A320_1930-20    Composants Majeurs  A320_1930
# 2      AILA320-A320_2237-20    Composants Majeurs  A320_2237
# 3      AILA320-A320_2497-20    Composants Majeurs  A320_2497
# 4      AILA320-A320_2562-20    Composants Majeurs  A320_2562
# ...                     ...                   ...        ...
# 10390  UNIE175-E175_4558-11  Composants Critiques  E175_4558
# 10391  UNIE175-E175_5414-11  Composants Critiques  E175_5414
# 10392  UNIE175-E175_5586-11  Composants Critiques  E175_5586
# 10393  UNIE175-E175_6729-11  Composants Critiques  E175_6729
# 10394  UNIE175-E175_6879-11  Composants Critiques  E175_6879
#
#                             desc  lifespan  taux_usure_actuel   cout
# 0                       Ailerons     10524          23.392968  10290
# 1                       Ailerons     10524          25.917596  10290
# ...

# %%
compo_final.to_csv(r'C:\Users\MAITE\Wild Code School\SkyAnalytics\BDD\fixes\compo_final.csv', index=False)
aeronefs.to_csv(r'C:\Users\MAITE\Wild Code School\SkyAnalytics\BDD\fixes\aeronefs_final.csv', index=False)
