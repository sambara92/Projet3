# %%
import os
from os import listdir
from os.path import isfile,join
from datetime import date, datetime,timedelta
import time
import requests
import pandas as pd

# %%
# I. Automatiser le téléchargement des fichiers log_vol et dégradations
# But : Créer un script qui télécharge l'ensemble des fichiers présents 

# Inconvénient : Télécharge à chaque fois tous les fichiers  
#               Ecrase les fichiers à chaque fois


## Pour info : Chemin du répertoire d'enregistrement des fichiers (où se trouve le notebook) 
working_directory = os.getcwd()
print(f"Chemin d'accès au répertoire : {working_directory}")

# Création d'un dossier pour stocker les fichiers téléchargés
os.makedirs("sauvegarde_log",exist_ok=True)
os.makedirs("sauvegarde_degra",exist_ok=True)
# Out:
# Chemin d'accès au répertoire : /Users/nadiaaitmada/Desktop/Wild/projet3

# %%
# Créer une fonction pour obtenir la date du jour
def get_today():
    today = datetime.today()
    return today.strftime("%Y-%m-%d")

# Récupérer année/mois/jour actuel
current_year = datetime.now().year
current_month = datetime.now().month
current_day = datetime.now().day

# Utiliser la fonction today
today = get_today()

# Construction de l'url de téléchargement en fonction du mois et du jour
# Construction de l'url de téléchargement en fonction du mois et du jour
for year in range(current_year,current_year+1):
    for month in range(current_month,current_month+1):
        for day in range(1,32):
            if year == current_year and month == current_month and day > current_day: # Ignorer les fichiers supérieurs à la date d'aujourd'hui
                continue
            url_log_vol = f"http://sc-e.fr/docs/logs_vols_2024-{month:02d}-{day:02d}.csv"
            file_log = f"sauvegarde_log/logs_vols_2024-{month:02d}-{day:02d}.csv"

            url_degrad = f"http://sc-e.fr/docs/degradations_2024-{month:02d}-{day:02d}.csv"
            file_degrad = f"sauvegarde_degra/degradations_2024-{month:02d}-{day:02d}.csv"

# Télécharger le fichier
            print(f"Téléchargement de {file_log}")
            print(f"Téléchargement de {file_degrad}")

            response = requests.get(url_log_vol)
            response = requests.get(url_degrad)

# Si réponse 200, on réalise le téléchargement
            if response.status_code == 200:
                with open(file_log,"wb") as file_log_vol:
                    file_log_vol.write(response.content)
                
                with open(file_degrad,"wb") as file_degradation:
                    file_degradation.write(response.content)
            else : 
                print(f"Téléchargement impossible de {file_log}. Code statut {response.status_code}")
                print(f"Téléchargement impossible de {file_degrad}. Code statut {response.status_code}")
print("Téléchargement terminé")
# Out:
# Téléchargement de sauvegarde_log/logs_vols_2024-06-01.csv
# Téléchargement de sauvegarde_degra/degradations_2024-06-01.csv
# Téléchargement impossible de sauvegarde_log/logs_vols_2024-06-01.csv. Code statut 404
# Téléchargement impossible de sauvegarde_degra/degradations_2024-06-01.csv. Code statut 404
# Téléchargement de sauvegarde_log/logs_vols_2024-06-02.csv
# Téléchargement de sauvegarde_degra/degradations_2024-06-02.csv
# Téléchargement impossible de sauvegarde_log/logs_vols_2024-06-02.csv. Code statut 404
# Téléchargement impossible de sauvegarde_degra/degradations_2024-06-02.csv. Code statut 404
# Téléchargement de sauvegarde_log/logs_vols_2024-06-03.csv
# Téléchargement de sauvegarde_degra/degradations_2024-06-03.csv
# Téléchargement de sauvegarde_log/logs_vols_2024-06-04.csv
# Téléchargement de sauvegarde_degra/degradations_2024-06-04.csv
# Téléchargement de sauvegarde_log/logs_vols_2024-06-05.csv
# Téléchargement de sauvegarde_degra/degradations_2024-06-05.csv
# Téléchargement de sauvegarde_log/logs_vols_2024-06-06.csv
# Téléchargement de sauvegarde_degra/degradations_2024-06-06.csv
# Téléchargement de sauvegarde_log/logs_vols_2024-06-07.csv
# Téléchargement de sauvegarde_degra/degradations_2024-06-07.csv
# Téléchargement de sauvegarde_log/logs_vols_2024-06-08.csv
# Téléchargement de sauvegarde_degra/degradations_2024-06-08.csv
# Téléchargement de sauvegarde_log/logs_vols_2024-06-09.csv
# Téléchargement de sauvegarde_degra/degradations_2024-06-09.csv
# Téléchargement de sauvegarde_log/logs_vols_2024-06-10.csv
# Téléchargement de sauvegarde_degra/degradations_2024-06-10.csv
# Téléchargement de sauvegarde_log/logs_vols_2024-06-11.csv
# Téléchargement de sauvegarde_degra/degradations_2024-06-11.csv
# Téléchargement terminé

# %%
# Vérifier le nombre de fichiers téléchargés dans sauvegarde_log
log_path = "./sauvegarde_log"
listfile_log = [file for file in listdir(log_path) if isfile(join(log_path,file))]
print(f" Nb fichier log_vol",len(listfile_log))

degra_path = "./sauvegarde_degra"
listfile_degra = [file for file in listdir(degra_path) if isfile(join(degra_path,file))]
print(f" Nb fichier degradation",len(listfile_degra))
# Out:
#  Nb fichier log_vol 10
#  Nb fichier degradation 10

# %%
# Vérifier l'ouverture d'un fichier log_vol
link_log = '/Users/nadiaaitmada/Desktop/Wild/projet3/sauvegarde_log/logs_vols_2024-06-07.csv'
df_log = pd.read_csv(link_log)
df_log.head()
# Out:
#    ref_deg linked_aero      compo_concerned  usure_nouvelle measure_day  \
# 0  D003661   E170_6353  REAE170-E170_6353-0       55.734745  2024-06-07
# 1  D009402   E170_6353  REAE170-E170_6353-1       52.646386  2024-06-07
# 2  D000812   E170_6353  SYSE170-E170_6353-2       18.691201  2024-06-07
# 3  D006665   E170_6353  ORDE170-E170_6353-3        8.595101  2024-06-07
# 4  D001163   E170_6353  AUTE170-E170_6353-4       44.795067  2024-06-07
#
#    need_replacement
# 0             False
# 1             False
# 2             False
# 3             False
# 4             False

# %%
# Vérifier l'ouverture d'un fichier degradation
link_degra = '/Users/nadiaaitmada/Desktop/Wild/projet3/sauvegarde_degra/degradations_2024-06-06.csv'
df_degra = pd.read_csv(link_degra)
df_degra.head()
# Out:
#    ref_deg linked_aero      compo_concerned  usure_nouvelle measure_day  \
# 0  D003661   E170_6353  REAE170-E170_6353-0       54.443290  2024-06-06
# 1  D009402   E170_6353  REAE170-E170_6353-1       51.297412  2024-06-06
# 2  D000812   E170_6353  SYSE170-E170_6353-2       17.647642  2024-06-06
# 3  D006665   E170_6353  ORDE170-E170_6353-3        7.561442  2024-06-06
# 4  D001163   E170_6353  AUTE170-E170_6353-4       43.325214  2024-06-06
#
#    need_replacement
# 0             False
# 1             False
# 2             False
# 3             False
# 4             False
